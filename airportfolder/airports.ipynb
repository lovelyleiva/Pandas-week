# %%
import pandas as pd
airports = pd.read_excel('airports.xlsx')

# %%
airports.shape #num of rows and columns
# Out:
# (73131, 18)

# %%
airports.info()#columns, types, and non-null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73131 entries, 0 to 73130
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 73131 non-null  int64
#  1   ident              73131 non-null  object
#  2   type               73131 non-null  object
#  3   name               73131 non-null  object
#  4   latitude_deg       73131 non-null  float64
#  5   longitude_deg      73131 non-null  float64
#  6   elevation_ft       59246 non-null  float64
#  7   continent          37662 non-null  object
#  8   iso_country        72872 non-null  object
#  9   iso_region         73131 non-null  object
#  10  municipality       67928 non-null  object
#  11  scheduled_service  73131 non-null  object
#  12  gps_code           42965 non-null  object
#  13  iata_code          9248 non-null   object
#  14  local_code         32924 non-null  object
#  15  home_link          3474 non-null   object
# ...

# %%
from bs4 import BeautifulSoup
import requests

def getHTML(url):
    response = requests.get(url)
    return response.text

html = getHTML('https://www.countrycode.org')
soup = BeautifulSoup(html, 'html.parser')

table = soup.find('table',attrs={'class':'main-table'})

countries = []

for row in table.find_all_next('tr'):
    cells = row.find_all_next('td')
    country = {}
    country['name'] = cells[0].string 
    countrycodes = cells[2].string 
    country['iso-2'] = countrycodes.split('/')[0]
    country['iso-3'] = countrycodes.split('/')[1]
    countries.append(country)

# %%
countries_df = pd.DataFrame(countries)

print(countries_df.tail(5))
# Out:
#                   name iso-2 iso-3
# 477  Wallis and Futuna   WF    WLF
# 478     Western Sahara   EH    ESH
# 479              Yemen   YE    YEM
# 480             Zambia   ZM    ZMB
# 481           Zimbabwe   ZW    ZWE

# %%
airports.isna()
# Out:
#           id  ident   type   name  latitude_deg  longitude_deg  elevation_ft  \
# 0      False  False  False  False         False          False         False
# 1      False  False  False  False         False          False         False
# 2      False  False  False  False         False          False         False
# 3      False  False  False  False         False          False         False
# 4      False  False  False  False         False          False         False
# ...      ...    ...    ...    ...           ...            ...           ...
# 73126  False  False  False  False         False          False         False
# 73127  False  False  False  False         False          False         False
# 73128  False  False  False  False         False          False         False
# 73129  False  False  False  False         False          False         False
# 73130  False  False  False  False         False          False         False
#
# ...

# %%
airports.continent.isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 73126    False
# 73127    False
# 73128     True
# 73129     True
# 73130    False
# Name: continent, Length: 73131, dtype: bool

# %%
airports[airports.continent.isna()] #looking for null continents
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 72921   26369      ZNC  small_airport                        Nyac Airport
# 72922  332195      ZNU  seaplane_base                Namu Water Aerodrome
# 73122  342103     ZYXW         closed                   Mt Logan Airstrip
# 73128  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 73129  342102     ZZZW         closed              Scandium City Heliport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# ...

# %%
airports[airports.continent.isna()].iso_country.unique() #filtering the null continents and printing the iso code
# Out:
# array(['US', 'PR', 'CO', 'AG', 'AI', 'MX', 'AW', 'GL', 'GB', 'BM', 'BQ',
#        'BS', 'BZ', 'CA', 'CR', 'CU', 'PA', 'DO', 'GT', 'GP', 'HN', 'HT',
#        'JM', 'KY', 'PM', 'TC', 'GD', 'NI', 'MQ', 'SV', 'MF', 'VI', 'BB',
#        'DM', 'BL', 'KN', 'LC', 'CW', 'SX', 'VG', 'MS', 'TT', 'VC', 'VE'],
#       dtype=object)

# %%
airports['continent'].fillna('NA', inplace = True) # replacing continent with NA

# %%
len(airports[airports.continent.isna()]) #checking that null length is now 0
# Out:
# 0

# %%
wiki_airports = airports.dropna(subset=['name','wikipedia_link'])

# %%
wiki_airports = wiki_airports[['name','wikipedia_link']]
wiki_airports.head()
# Out:
#                               name  \
# 45   McKenzie Bridge State Airport
# 69                   Grant Airport
# 231                 Utirik Airport
# 250            Sandy River Airport
# 376              Vernonia Airfield
#
#                                         wikipedia_link
# 45   https://en.wikipedia.org/wiki/McKenzie_Bridge_...
# 69         https://en.wikipedia.org/wiki/Grant_Airport
# 231       https://en.wikipedia.org/wiki/Utirik_Airport
# 250  https://en.wikipedia.org/wiki/Sandy_River_Airport
# 376    https://en.wikipedia.org/wiki/Vernonia_Airfield

# %%
countries_and_regions = airports[['iso_country','iso_region']] #store them in their own DataFrame
countries_and_regions.duplicated() #check for dupes
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73126     True
# 73127     True
# 73128     True
# 73129     True
# 73130     True
# Length: 73131, dtype: bool

# %%
cleaned_countries_and_regions = countries_and_regions.drop_duplicates() #droping dupes
cleaned_countries_and_regions.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 72915    False
# 72916    False
# 72918    False
# 72919    False
# 72920    False
# Length: 2868, dtype: bool

# %%
import pandas as pd
airports = pd.read_excel('airports.xlsx',keep_default_na=False)

# %%
airports.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601           11        NA          US      US-PA
# 1     38.704022    -101.473911         3435        NA          US      US-KS
# 2     59.947733    -151.692524          450        NA          US      US-AK
# 3     34.864799     -86.770302          820        NA          US      US-AL
# 4     35.608700     -91.254898          237        NA          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
airports = airports [['name','continent','iso_country','iso_region','latitude_deg','longitude_deg']]

# %%
airports.continent.unique()
# Out:
# array(['NA', 'OC', 'AF', 'AN', 'EU', 'AS', 'SA'], dtype=object)

# %%
na_airports = airports[airports.continent == 'NA']

# %%
na_airports.describe()
# Out:
#        latitude_deg  longitude_deg
# count  35469.000000   35469.000000
# mean      38.147809     -96.508971
# std        9.296945      18.380338
# min       -2.144851    -178.656380
# 25%       32.699280    -108.276001
# 50%       38.436001     -94.647583
# 75%       42.948601     -83.383499
# max       82.750000     179.275997

# %%
na_airports.info() #where is elevation?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35469 entries, 0 to 73129
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           35469 non-null  object
#  1   continent      35469 non-null  object
#  2   iso_country    35469 non-null  object
#  3   iso_region     35469 non-null  object
#  4   latitude_deg   35469 non-null  float64
#  5   longitude_deg  35469 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.9+ MB

# %%
na_airports['elevation_ft'] = pd.to_numeric(airports['elevation_ft'])
na_airports.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Stephanie Leiva\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Stephanie Leiva\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Stephanie Leiva\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'elevation_ft'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
na_airports.describe()
