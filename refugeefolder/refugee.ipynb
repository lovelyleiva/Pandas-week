# %%
import pandas as pd
refasylum = pd.read_csv('refasylum.txt')

# %%
# Before reading into python, edit the text in the notes app. This is b/c python is upset with the formatted blanks.
# Delete first 4 lines up to the column names ("Country Name","Country Code", etc)
# replacing the spaces in column names with _ (python does not take spaces in names)
# adding _ in front of the years (python does not take anything starting with numbers)
#remove Indicator Code, indicator name,  and Unnamed:66 (if exists)

# %%
refasylum.columns = [c.replace(' ', '_') for c in refasylum.columns]
# for i in refasylum.columns[4:-1]:
#     refasylum.rename(columns={i:f'_{i}'},inplace=True)

# %%
refasylum.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Indicator_Name', 'Indicator_Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed:_66'],
#       dtype='object')

# %%
refasylum = refasylum.drop("Indicator_Name", axis = 1)
refasylum = refasylum.drop("Indicator_Code", axis = 1)
refasylum = refasylum.drop("Unnamed:_66", axis = 1)

# %%
refasylum.head()
# Out:
#                   Country_Name Country_Code  1960  1961  1962  1963  1964  \
# 0                        Aruba          ABW   NaN   NaN   NaN   NaN   NaN
# 1  Africa Eastern and Southern          AFE   NaN   NaN   NaN   NaN   NaN
# 2                  Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN
# 3   Africa Western and Central          AFW   NaN   NaN   NaN   NaN   NaN
# 4                       Angola          AGO   NaN   NaN   NaN   NaN   NaN
#
#    1965  1966  1967  ...       2012       2013       2014       2015  \
# 0   NaN   NaN   NaN  ...        NaN        NaN        NaN        NaN
# 1   NaN   NaN   NaN  ...  1900709.0  2054335.0  2637640.0  3333273.0
# 2   NaN   NaN   NaN  ...    16184.0    16861.0   300421.0   257553.0
# 3   NaN   NaN   NaN  ...   934976.0   951229.0  1108169.0  1138010.0
# 4   NaN   NaN   NaN  ...    23401.0    23771.0    15468.0    15547.0
#
#         2016       2017       2018       2019       2020       2021
# ...

# %%
refasylum.columns
# Out:
# Index(['Country_Name', 'Country_Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
refasylum[['Country_Name', '2021']]

new = refasylum.groupby('Country_Name')['2021'].sum().sort_values(ascending=True)
new.head(55)
#54 countries did not take in any refugees
# Turks and Caicos Islands           7.0
# Mauritius                         10.0
# Bahamas, The                      10.0
#Turkmenistan                      16.0
#Monaco                            17.0


# agg({'Price':['min','max','median','sum'],'Weight':['min','max','median']})

# Souvenirs.groupby('CategoryName')['Price'].sum()
# Out:
# Country_Name
# New Caledonia                     0.0
# St. Martin (French part)          0.0
# St. Vincent and the Grenadines    0.0
# Equatorial Guinea                 0.0
# Kosovo                            0.0
# Timor-Leste                       0.0
# Tonga                             0.0
# St. Lucia                         0.0
# Dominica                          0.0
# Samoa                             0.0
# Palau                             0.0
# Macao SAR, China                  0.0
# Maldives                          0.0
# Channel Islands                   0.0
# Marshall Islands                  0.0
# Lao PDR                           0.0
# Tuvalu                            0.0
# St. Kitts and Nevis               0.0
# Faroe Islands                     0.0
# Sao Tome and Principe             0.0
# Isle of Man                       0.0
# Seychelles                        0.0
# Singapore                         0.0
# Haiti                             0.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

ax = refasylum.plot(title = 'B',kind='barh')
ax.set_xlabel('Country_Name')
ax.set_ylabel('2021')
plt.show()

# %%
#Who took in the most refugees
# ##############WHOO TOOK IN THE LEAST
#Who has the biggest net change

# %%
refasylumT = refasylum.copy()
refasylumT = refasylumT.drop("Country_Code", axis = 1)
refasylumT = refasylumT.T
refasylumT.columns = refasylumT.iloc[0]
refasylumT = refasylumT.rename(columns = {"Country_Name":"Year"})
refasylumT.reset_index(level=0, inplace =True)
refasylumT = refasylumT.rename(columns={"index":"Year"})
refasylumT = refasylumT.drop([0])
print(refasylumT.columns)
refasylumT.head(10)
# Out:
# Index(['Year', 'Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country_Name', length=267)
# Country_Name  Year Aruba Africa Eastern and Southern Afghanistan  \
# 1             1960   NaN                         NaN         NaN
# 2             1961   NaN                         NaN         NaN
# 3             1962   NaN                         NaN         NaN
# 4             1963   NaN                         NaN         NaN
# 5             1964   NaN                         NaN         NaN
# 6             1965   NaN                         NaN         NaN
# 7             1966   NaN                         NaN         NaN
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use("fivethirtyeight")

#setting figure size to 12,10
fig, ax = plt.subplots(figsize=(12,10))

#Labelling the axes and setting a title
plt.xlabel("Year")
plt.xlabel("Values")
plt.title("ABC")

#plotting the "A" column aling
plt.plot(refasylumT["Year"], refasylumT["United States"])
plt.xticks([0,61])
plt.show()

# %%
minimum = refasylumT[['Year','Turks and Caicos Islands','Mauritius','Bahamas, The','Turkmenistan', 'Monaco']]
minimum
# Out:
# Country_Name  Year Turks and Caicos Islands Mauritius Bahamas, The  \
# 1             1960                      NaN       NaN          NaN
# 2             1961                      NaN       NaN          NaN
# 3             1962                      NaN       NaN          NaN
# 4             1963                      NaN       NaN          NaN
# 5             1964                      NaN       NaN          NaN
# ..             ...                      ...       ...          ...
# 58            2017                      5.0       5.0          8.0
# 59            2018                      5.0      16.0         14.0
# 60            2019                      5.0      20.0         10.0
# 61            2020                      8.0      20.0         15.0
# 62            2021                      7.0      10.0         10.0
#
# Country_Name Turkmenistan Monaco
# 1                     NaN    NaN
# 2                     NaN    NaN
# 3                     NaN    NaN
# ...

# %%
from cProfile import label
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use("fivethirtyeight")

#setting figure size to 12,10
fig, ax = plt.subplots(figsize=(12,10))

#Labelling the axes and setting a title
plt.xlabel("Year")
plt.ylabel("Values")
plt.title("Bottom 5 Countries with Refugees in 2021")

#plotting the "A" column aling
plt.plot(minimum["Year"], minimum["Turks and Caicos Islands"], label = 'Turks and Caicos Islands')
plt.plot(minimum["Year"], minimum["Mauritius"], label = 'Mauritius')
#plt.plot(minimum["Year"], minimum["Bahamas, The"], label = 'The Bahamas')
#plt.plot(minimum["Year"], minimum["Turkmenistan"], label = 'Turkmenistan')
plt.plot(minimum["Year"], minimum["Monaco"], label = 'Monaco')
plt.legend(loc = "upper right")
#plt.xlim([1900,2020])
plt.xticks([50,61])
plt.show()
