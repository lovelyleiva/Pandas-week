# %%
import pandas as pd
payment = pd.read_csv('chefmozaccepts.csv')

# %%
payment.head()
# Out:
#    placeID             Rpayment
# 0   135110                 cash
# 1   135110                 VISA
# 2   135110  MasterCard-Eurocard
# 3   135110     American_Express
# 4   135110     bank_debit_cards

# %%
place = pd.read_csv('geoplaces2.csv')
place.head()
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
# 2   135106  22.149709 -100.976093
# 3   132667  23.752697  -99.163359
# 4   132613  23.752903  -99.165076
#
#                                       the_geom_meter  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...
# 1  0101000020957F00001AD016568C4858C1243261274BA5...
# 2  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                              name                                 address  \
# 0                 Kiku Cuernavaca                              Revolucion
# 1                 puesto de tacos  esquina santos degollado y leon guzman
# 2      El Rinc�n de San Francisco                         Universidad 169
# 3  little pizza Emilio Portes Gil                 calle emilio portes gil
# ...

# %%
play_n_place = payment.merge(place, how='inner',on = 'placeID')

# %%
play_n_place = play_n_place[['Rpayment','name']]
play_n_place.head()
# Out:
#               Rpayment                        name
# 0                 cash                   Paniroles
# 1                 cash  El Rinc�n de San Francisco
# 2                 VISA  El Rinc�n de San Francisco
# 3  MasterCard-Eurocard  El Rinc�n de San Francisco
# 4                 cash                        vips

# %%
play_n_place.name.value_counts()
# Out:
# La Posada del Virrey    5
# shi ro ie               5
# Carls Jr                5
# emilianos               5
# tacos los volcanes      5
#                        ..
# el pueblito             1
# cafe punta del cielo    1
# crudalia                1
# Hamburguesas saul       1
# puesto de gorditas      1
# Name: name, Length: 113, dtype: int64

# %%
#payment methods for each place
play_n_place[play_n_place.name=='La Posada del Virrey'] #do this for each restaurant name?
# Out:
#                 Rpayment                  name
# 194                 cash  La Posada del Virrey
# 195                 VISA  La Posada del Virrey
# 196  MasterCard-Eurocard  La Posada del Virrey
# 197     American_Express  La Posada del Virrey
# 198     bank_debit_cards  La Posada del Virrey

# %%
#payment methods for each place
play_n_place.groupby('name')['Rpayment'].apply(lambda x: ",".join(x)) #patrick's solution 1
# Out:
# name
# Abondance Restaurante Bar                                                          cash
# Arrachela Grill                                                                    cash
# Cabana Huasteca                                                                    cash
# Cafe Chaires                                                                       cash
# Cafeteria cenidet                                                                  cash
#                                                             ...
# tacos de barbacoa enfrente del Tec                                                 cash
# tacos de la estacion                                                               cash
# tacos los volcanes                    cash,VISA,MasterCard-Eurocard,American_Express...
# tortas hawai                                                                       cash
# vips                                                      cash,VISA,MasterCard-Eurocard
# ...

# %%
play_n_place.groupby('name')['Rpayment'].apply(list) #patrick solution #2
# Out:
# name
# Abondance Restaurante Bar                                                        [cash]
# Arrachela Grill                                                                  [cash]
# Cabana Huasteca                                                                  [cash]
# Cafe Chaires                                                                     [cash]
# Cafeteria cenidet                                                                [cash]
#                                                             ...
# tacos de barbacoa enfrente del Tec                                               [cash]
# tacos de la estacion                                                             [cash]
# tacos los volcanes                    [cash, VISA, MasterCard-Eurocard, American_Exp...
# tortas hawai                                                                     [cash]
# vips                                                  [cash, VISA, MasterCard-Eurocard]
# ...

# %%
parking = pd.read_csv('chefmozparking.csv')
parking.head()
# Out:
#    placeID parking_lot
# 0   135111      public
# 1   135110        none
# 2   135109        none
# 3   135108        none
# 4   135107        none

# %%
park_n_place = parking.merge(place, how='inner',on = 'placeID')
park_n_place = park_n_place[['parking_lot','name']]
park_n_place.head()
# Out:
#   parking_lot                        name
# 0        none                   Paniroles
# 1        none                  Potzocalli
# 2        none  El Rinc�n de San Francisco
# 3         yes                        vips
# 4      public           Cafeteria cenidet

# %%
#What are the parking statuses for each place?
park_n_place.groupby('name')['parking_lot'].apply(list)
# Out:
# name
# Abondance Restaurante Bar                [yes]
# Arrachela Grill                         [none]
# Cabana Huasteca                         [none]
# Cafe Chaires                             [yes]
# Cafeteria cenidet                     [public]
#                                         ...
# tacos de barbacoa enfrente del Tec    [public]
# tacos de la estacion                    [none]
# tacos los volcanes                      [none]
# tortas hawai                          [public]
# vips                                     [yes]
# Name: parking_lot, Length: 129, dtype: object

# %%
#skipping cuisine for each palce. it's the same thing.

# %%
#What is the average rating, average food rating, average service rating, minimum food rating, minimum service rating, and maximum service rating for the restaurants by cuisine?
ratings = pd.read_csv('rating_final.csv')
avgRating = ratings['rating'].describe()['mean']
maxServiceRating = ratings['service_rating'].describe()['max']
print('average rating', avgRating)
print('max service rating', maxServiceRating)
#skipping the others. it's basically the same.
# Out:
# average rating 1.1998277347114557
# max service rating 2.0

# %%
#What are the payment methods preferred by social drinkers?
#What are the cuisines preferred by eco-friendly users?

profile = pd.read_csv('userprofile.csv')
uCuisine = pd.read_csv('usercuisine.csv')

profile['interest'].unique() #dupes
profile.head()
# Out:
#   userID   latitude   longitude smoker     drink_level dress_preference  \
# 0  U1001  22.139997 -100.978803  false      abstemious         informal
# 1  U1002  22.150087 -100.983325  false      abstemious         informal
# 2  U1003  22.119847 -100.946527  false  social drinker           formal
# 3  U1004  18.867000  -99.183000  false      abstemious         informal
# 4  U1005  22.183477 -100.959891  false      abstemious    no preference
#
#   ambience transport marital_status        hijos  birth_year    interest  \
# 0   family   on foot         single  independent        1989     variety
# 1   family    public         single  independent        1990  technology
# 2   family    public         single  independent        1989        none
# 3   family    public         single  independent        1940     variety
# 4   family    public         single  independent        1992        none
#
#            personality  religion      activity  color  weight  budget  height
# ...

# %%
profile = profile[['userID','interest']]
profile_n_ucuisine = profile.merge(uCuisine, how = 'inner', on ='userID')
profile_n_ucuisine = profile_n_ucuisine[profile_n_ucuisine.interest =='eco-friendly'] #like stephen king examply in lesson
profile_n_ucuisine.groupby(['userID','Rcuisine'])[[]].count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(U1016, American), (U1016, Barbecue), (U1016, Cafe-Coffee_Shop), (U1016, Contemporary), (U1016, Eastern_European), (U1016, Fusion), (U1016, Indian-Pakistani), (U1016, Japanese), (U1016, Lebanese), (U1016, Moroccan), (U1016, Polish), (U1016, Polynesian), (U1016, Portuguese), (U1016, Regional), (U1030, Mexican), (U1041, Contemporary), (U1048, Mexican), (U1063, Mexican), (U1072, Mexican), (U1074, Sushi), (U1091, American), (U1091, Mexican), (U1096, Mexican), (U1100, Mexican), (U1101, Afghan), (U1101, Australian), (U1101, Bar), (U1101, Burgers), (U1101, Cafe-Coffee_Shop), (U1101, Cafeteria), (U1101, Chinese), (U1101, Contemporary), (U1101, Diner), (U1101, Doughnuts), (U1101, Family), (U1101, Hot_Dogs), (U1101, Italian), (U1101, Latin_American), (U1101, Mexican), (U1102, Pizzeria), (U1109, Mexican), (U1119, Mexican), (U1131, Mexican), (U1137, Mexican)]

# %%
#skipping payments preferred by social drinkers, preferred by students, cuisine by catholic
#diff merges but all the same idea.
